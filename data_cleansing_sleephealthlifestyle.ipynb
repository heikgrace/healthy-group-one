# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("data/sleephealthlifestyle/sleep_health_and_lifestyle_dataset.csv")

# %%
data
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %% [markdown]
# ## 1. inspecting a dataframe

# %%
data.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
data.describe()
# Out:
#         Person ID         Age  Sleep Duration  Quality of Sleep  \
# count  374.000000  374.000000      374.000000        374.000000
# mean   187.500000   42.184492        7.132086          7.312834
# std    108.108742    8.673133        0.795657          1.196956
# min      1.000000   27.000000        5.800000          4.000000
# 25%     94.250000   35.250000        6.400000          6.000000
# 50%    187.500000   43.000000        7.200000          7.000000
# 75%    280.750000   50.000000        7.800000          8.000000
# max    374.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count               374.000000    374.000000  374.000000    374.000000
# mean                 59.171123      5.385027   70.165775   6816.844920
# std                  20.830804      1.774526    4.135676   1617.915679
# min                  30.000000      3.000000   65.000000   3000.000000
# ...

# %%
data.describe(include='O') # includes objects
# Out:
#        Gender Occupation BMI Category Blood Pressure Sleep Disorder
# count     374        374          374            374            155
# unique      2         11            4             25              2
# top      Male      Nurse       Normal         130/85    Sleep Apnea
# freq      189         73          195             99             78

# %%
# checking for missing values

data.isnull()
# Out:
#      Person ID  Gender    Age  Occupation  Sleep Duration  Quality of Sleep  \
# 0        False   False  False       False           False             False
# 1        False   False  False       False           False             False
# 2        False   False  False       False           False             False
# 3        False   False  False       False           False             False
# 4        False   False  False       False           False             False
# ..         ...     ...    ...         ...             ...               ...
# 369      False   False  False       False           False             False
# 370      False   False  False       False           False             False
# 371      False   False  False       False           False             False
# 372      False   False  False       False           False             False
# 373      False   False  False       False           False             False
#
# ...

# %%
data.isnull().sum()
# Out:
# Person ID                    0
# Gender                       0
# Age                          0
# Occupation                   0
# Sleep Duration               0
# Quality of Sleep             0
# Physical Activity Level      0
# Stress Level                 0
# BMI Category                 0
# Blood Pressure               0
# Heart Rate                   0
# Daily Steps                  0
# Sleep Disorder             219
# dtype: int64

# %%
data.drop_duplicates(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
data_prepared_columns = data.drop(['Person ID'], axis=1)

# %%
print(data_prepared_columns.columns)
# Out:
# Index(['Gender', 'Age', 'Occupation', 'Sleep Duration', 'Quality of Sleep',
#        'Physical Activity Level', 'Stress Level', 'BMI Category',
#        'Blood Pressure', 'Heart Rate', 'Daily Steps', 'Sleep Disorder'],
#       dtype='object')

# %%
data_prepared_columns
# Out:
#      Gender  Age            Occupation  Sleep Duration  Quality of Sleep  \
# 0      Male   27     Software Engineer             6.1                 6
# 1      Male   28                Doctor             6.2                 6
# 2      Male   28                Doctor             6.2                 6
# 3      Male   28  Sales Representative             5.9                 4
# 4      Male   28  Sales Representative             5.9                 4
# ..      ...  ...                   ...             ...               ...
# 369  Female   59                 Nurse             8.1                 9
# 370  Female   59                 Nurse             8.0                 9
# 371  Female   59                 Nurse             8.1                 9
# 372  Female   59                 Nurse             8.1                 9
# 373  Female   59                 Nurse             8.1                 9
#
#      Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# ...

# %%
print(data_prepared_columns.columns)
# Out:
# Index(['Gender', 'Age', 'Occupation', 'Sleep Duration', 'Quality of Sleep',
#        'Physical Activity Level', 'Stress Level', 'BMI Category',
#        'Blood Pressure', 'Heart Rate', 'Daily Steps', 'Sleep Disorder'],
#       dtype='object')

# %%
# Spalte aufteilen
data_prepared_columns[['Blood Pressure systolic', 'Blood Pressure diastolic']] = data_prepared_columns['Blood Pressure'].str.split('/', expand=True)

# Optional: Werte in Integer umwandeln
data_prepared_columns['Blood Pressure systolic'] = data_prepared_columns['Blood Pressure systolic'].astype(int)
data_prepared_columns['Blood Pressure diastolic'] = data_prepared_columns['Blood Pressure diastolic'].astype(int)

data_prepared_columns
# Out:
#      Gender  Age            Occupation  Sleep Duration  Quality of Sleep  \
# 0      Male   27     Software Engineer             6.1                 6
# 1      Male   28                Doctor             6.2                 6
# 2      Male   28                Doctor             6.2                 6
# 3      Male   28  Sales Representative             5.9                 4
# 4      Male   28  Sales Representative             5.9                 4
# ..      ...  ...                   ...             ...               ...
# 369  Female   59                 Nurse             8.1                 9
# 370  Female   59                 Nurse             8.0                 9
# 371  Female   59                 Nurse             8.1                 9
# 372  Female   59                 Nurse             8.1                 9
# 373  Female   59                 Nurse             8.1                 9
#
#      Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# ...

# %%
# Schritt 1: Spaltenliste holen
cols = list(data_prepared_columns.columns)

# Schritt 2: Zielspalten entfernen, um sie später wieder einzufügen
cols.remove('Blood Pressure systolic')
cols.remove('Blood Pressure diastolic')

# Schritt 3: Neue Spalten an Position 8 und 9 einfügen
cols.insert(8, 'Blood Pressure systolic')
cols.insert(9, 'Blood Pressure diastolic')

# Schritt 4: DataFrame neu anordnen
data_prepared_columns = data_prepared_columns[cols]

# %%
data_prepared_columns
# Out:
#      Gender  Age            Occupation  Sleep Duration  Quality of Sleep  \
# 0      Male   27     Software Engineer             6.1                 6
# 1      Male   28                Doctor             6.2                 6
# 2      Male   28                Doctor             6.2                 6
# 3      Male   28  Sales Representative             5.9                 4
# 4      Male   28  Sales Representative             5.9                 4
# ..      ...  ...                   ...             ...               ...
# 369  Female   59                 Nurse             8.1                 9
# 370  Female   59                 Nurse             8.0                 9
# 371  Female   59                 Nurse             8.1                 9
# 372  Female   59                 Nurse             8.1                 9
# 373  Female   59                 Nurse             8.1                 9
#
#      Physical Activity Level  Stress Level BMI Category  \
# ...

# %%
data_prepared_columns = data_prepared_columns.drop(columns=['Blood Pressure'])

# %%
data_prepared_columns
# Out:
#      Gender  Age            Occupation  Sleep Duration  Quality of Sleep  \
# 0      Male   27     Software Engineer             6.1                 6
# 1      Male   28                Doctor             6.2                 6
# 2      Male   28                Doctor             6.2                 6
# 3      Male   28  Sales Representative             5.9                 4
# 4      Male   28  Sales Representative             5.9                 4
# ..      ...  ...                   ...             ...               ...
# 369  Female   59                 Nurse             8.1                 9
# 370  Female   59                 Nurse             8.0                 9
# 371  Female   59                 Nurse             8.1                 9
# 372  Female   59                 Nurse             8.1                 9
# 373  Female   59                 Nurse             8.1                 9
#
#      Physical Activity Level  Stress Level BMI Category  \
# ...

# %%
data_prepared_columns.isna().sum()
# Out:
# Gender                        0
# Age                           0
# Occupation                    0
# Sleep Duration                0
# Quality of Sleep              0
# Physical Activity Level       0
# Stress Level                  0
# BMI Category                  0
# Blood Pressure systolic       0
# Blood Pressure diastolic      0
# Heart Rate                    0
# Daily Steps                   0
# Sleep Disorder              219
# dtype: int64

# %%
data_prepared_columns = data_prepared_columns.fillna('')

# %%
data_prepared_columns.isna().sum()
# Out:
# Gender                      0
# Age                         0
# Occupation                  0
# Sleep Duration              0
# Quality of Sleep            0
# Physical Activity Level     0
# Stress Level                0
# BMI Category                0
# Blood Pressure systolic     0
# Blood Pressure diastolic    0
# Heart Rate                  0
# Daily Steps                 0
# Sleep Disorder              0
# dtype: int64

# %%
data_prepared_columns.head()
# Out:
#   Gender  Age            Occupation  Sleep Duration  Quality of Sleep  \
# 0   Male   27     Software Engineer             6.1                 6
# 1   Male   28                Doctor             6.2                 6
# 2   Male   28                Doctor             6.2                 6
# 3   Male   28  Sales Representative             5.9                 4
# 4   Male   28  Sales Representative             5.9                 4
#
#    Physical Activity Level  Stress Level BMI Category  \
# 0                       42             6   Overweight
# 1                       60             8       Normal
# 2                       60             8       Normal
# 3                       30             8        Obese
# 4                       30             8        Obese
#
#    Blood Pressure systolic  Blood Pressure diastolic  Heart Rate  Daily Steps  \
# 0                      126                        83          77         4200
# ...

# %%
data_prepared_columns.describe()
# Out:
#               Age  Sleep Duration  Quality of Sleep  Physical Activity Level  \
# count  374.000000      374.000000        374.000000               374.000000
# mean    42.184492        7.132086          7.312834                59.171123
# std      8.673133        0.795657          1.196956                20.830804
# min     27.000000        5.800000          4.000000                30.000000
# 25%     35.250000        6.400000          6.000000                45.000000
# 50%     43.000000        7.200000          7.000000                60.000000
# 75%     50.000000        7.800000          8.000000                75.000000
# max     59.000000        8.500000          9.000000                90.000000
#
#        Stress Level  Blood Pressure systolic  Blood Pressure diastolic  \
# count    374.000000               374.000000                374.000000
# mean       5.385027               128.553476                 84.649733
# ...

# %%
data_gender_female = data_prepared_columns[data_prepared_columns['Gender'] == 'Female']
data_gender_male = data_prepared_columns[data_prepared_columns['Gender'] == 'Male']

# %%
data_gender_male
# Out:
#     Gender  Age            Occupation  Sleep Duration  Quality of Sleep  \
# 0     Male   27     Software Engineer             6.1                 6
# 1     Male   28                Doctor             6.2                 6
# 2     Male   28                Doctor             6.2                 6
# 3     Male   28  Sales Representative             5.9                 4
# 4     Male   28  Sales Representative             5.9                 4
# ..     ...  ...                   ...             ...               ...
# 249   Male   44           Salesperson             6.5                 6
# 264   Male   48                Doctor             7.3                 7
# 266   Male   48                Doctor             7.3                 7
# 276   Male   49                Doctor             8.1                 9
# 277   Male   49                Doctor             8.1                 9
#
#      Physical Activity Level  Stress Level BMI Category  \
# ...

# %%
#exclude 18-22 and 65-79?
#1: 23-30
#2: 31-40
#3: 41-50
#4: 51-65

#Create new column with age group
bins = [20, 35, 50, 65]
labels = ['Young Adult', 'Adult', 'Senior']


# Neue Spalte 'age_group' hinzufügen
data_gender_female['Age_group'] = pd.cut(data_gender_female['Age'], bins=bins, labels=labels)
data_gender_male['Age_group'] = pd.cut(data_gender_male['Age'], bins=bins, labels=labels)
# Out:
# C:\Users\Graceffa\AppData\Local\Temp\ipykernel_25648\1636006442.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_gender_female['Age_group'] = pd.cut(data_gender_female['Age'], bins=bins, labels=labels)
# C:\Users\Graceffa\AppData\Local\Temp\ipykernel_25648\1636006442.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_gender_male['Age_group'] = pd.cut(data_gender_male['Age'], bins=bins, labels=labels)

# %%
data_gender_female
# Out:
#      Gender  Age Occupation  Sleep Duration  Quality of Sleep  \
# 16   Female   29      Nurse             6.5                 5
# 18   Female   29      Nurse             6.5                 5
# 30   Female   30      Nurse             6.4                 5
# 31   Female   30      Nurse             6.4                 5
# 32   Female   31      Nurse             7.9                 8
# ..      ...  ...        ...             ...               ...
# 369  Female   59      Nurse             8.1                 9
# 370  Female   59      Nurse             8.0                 9
# 371  Female   59      Nurse             8.1                 9
# 372  Female   59      Nurse             8.1                 9
# 373  Female   59      Nurse             8.1                 9
#
#      Physical Activity Level  Stress Level   BMI Category  \
# 16                        40             7  Normal Weight
# 18                        40             7  Normal Weight
# ...

# %%
#Sort age group after "age"
cols = list(data_gender_female.columns)
cols.insert(1, cols.pop(cols.index('Age_group')))
data_gender_female = data_gender_female[cols]

# %%
#Sort age group after "age"
cols = list(data_gender_male.columns)
cols.insert(1, cols.pop(cols.index('Age_group')))
data_gender_male = data_gender_male[cols]

# %%
#delete all NaN values
data_gender_female_corrected = data_gender_female.dropna(subset=['Age_group'])
data_gender_male_corrected = data_gender_male.dropna(subset=['Age_group'])

# %%
data_gender_female_corrected['BMI Category'] = data_gender_female_corrected['BMI Category'].replace('Normal', 'Normal Weight')
data_gender_male_corrected['BMI Category'] = data_gender_male_corrected['BMI Category'].replace('Normal', 'Normal Weight')

# %%
data_gender_female_corrected
# Out:
#      Gender    Age_group  Age Occupation  Sleep Duration  Quality of Sleep  \
# 16   Female  Young Adult   29      Nurse             6.5                 5
# 18   Female  Young Adult   29      Nurse             6.5                 5
# 30   Female  Young Adult   30      Nurse             6.4                 5
# 31   Female  Young Adult   30      Nurse             6.4                 5
# 32   Female  Young Adult   31      Nurse             7.9                 8
# ..      ...          ...  ...        ...             ...               ...
# 369  Female       Senior   59      Nurse             8.1                 9
# 370  Female       Senior   59      Nurse             8.0                 9
# 371  Female       Senior   59      Nurse             8.1                 9
# 372  Female       Senior   59      Nurse             8.1                 9
# 373  Female       Senior   59      Nurse             8.1                 9
#
#      Physical Activity Level  Stress Level   BMI Category  \
# ...

# %%
data_gender_female_corrected.isna().sum()
# Out:
# Gender                      0
# Age_group                   0
# Age                         0
# Occupation                  0
# Sleep Duration              0
# Quality of Sleep            0
# Physical Activity Level     0
# Stress Level                0
# BMI Category                0
# Blood Pressure systolic     0
# Blood Pressure diastolic    0
# Heart Rate                  0
# Daily Steps                 0
# Sleep Disorder              0
# dtype: int64

# %%
data_gender_female_corrected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 185 entries, 16 to 373
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Gender                    185 non-null    object
#  1   Age_group                 185 non-null    category
#  2   Age                       185 non-null    int64
#  3   Occupation                185 non-null    object
#  4   Sleep Duration            185 non-null    float64
#  5   Quality of Sleep          185 non-null    int64
#  6   Physical Activity Level   185 non-null    int64
#  7   Stress Level              185 non-null    int64
#  8   BMI Category              185 non-null    object
#  9   Blood Pressure systolic   185 non-null    int64
#  10  Blood Pressure diastolic  185 non-null    int64
#  11  Heart Rate                185 non-null    int64
#  12  Daily Steps               185 non-null    int64
#  13  Sleep Disorder            185 non-null    object
# ...

# %%
data_gender_female_corrected.to_csv('data/sleephealthlifestyle/data_gender_female.csv', index=False)
data_gender_male_corrected.to_csv('data/sleephealthlifestyle/data_gender_male.csv', index=False)

# %%
combined_df = pd.concat([data_gender_female_corrected, data_gender_male_corrected], ignore_index=True)
combined_df.to_csv('data/sleephealthlifestyle/data_gender_combined.csv', index=False)
