# %%
import pandas as pd
import numpy as np

# %%
fitbit_data = pd.read_csv("data/fitbit_sema/fitbit_data_prep.csv")

# %%
fitbit_data
# Out:
#       id  age     age_group  gender   bmi    rmssd  stress_score  \
# 0      1  <30  young adults    male   <19   89.603          78.0
# 1      1  <30  young adults    male   <19   94.303          80.0
# 2      1  <30  young adults    male   <19  119.212          84.0
# 3      1  <30  young adults    male   <19  111.709          82.0
# 4      1  <30  young adults    male   <19  103.034          81.0
# ...   ..  ...           ...     ...   ...      ...           ...
# 1562  31  <30  young adults  female  23.0   19.407          84.0
# 1563  31  <30  young adults  female  23.0   22.892          84.0
# 1564  31  <30  young adults  female  23.0   22.888          89.0
# 1565  31  <30  young adults  female  23.0   21.189          82.0
# 1566  31  <30  young adults  female  23.0   20.818          84.0
#
#       sleep_points_percentage  calories  distance        bpm  \
# 0                    0.833333   2351.59    6517.5  71.701565
# ...

# %%
fitbit_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1567 entries, 0 to 1566
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         1567 non-null   int64
#  1   age                        1567 non-null   object
#  2   age_group                  1567 non-null   object
#  3   gender                     1567 non-null   object
#  4   bmi                        1567 non-null   object
#  5   rmssd                      1567 non-null   float64
#  6   stress_score               1567 non-null   float64
#  7   sleep_points_percentage    1567 non-null   float64
#  8   calories                   1567 non-null   float64
#  9   distance                   1567 non-null   float64
#  10  bpm                        1567 non-null   float64
#  11  lightly_active_minutes     1567 non-null   float64
#  12  moderately_active_minutes  1567 non-null   float64
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(data=fitbit_data, x='id', bins=31, kde=True)
plt.title('Distribution of ID')
plt.xlabel('ID')
plt.ylabel('Count')
plt.show()

# %%
fitbit_data[fitbit_data['id'] == 15]
# Out:
#      id   age age_group gender   bmi   rmssd  stress_score  \
# 766  15  >=30    adults   male  >=30  24.910          67.0
# 767  15  >=30    adults   male  >=30  29.962          67.0
#
#      sleep_points_percentage  calories  distance        bpm  \
# 766                 0.700000   4808.73   11392.3  77.945980
# 767                 0.666667   3044.46    1412.7  74.016954
#
#      lightly_active_minutes  moderately_active_minutes  very_active_minutes  \
# 766                   108.0                       49.0                172.0
# 767                   112.0                        7.0                  3.0
#
#      sedentary_minutes  sleep_duration  sleep_efficiency    steps
# 766              590.0        8.683333              95.0  15347.0
# 767              964.0        5.900000              93.0   1908.0

# %%
fitbit_data['id'].value_counts().min()
# Out:
# np.int64(2)

# %%
fitbit_data[fitbit_data['stress_score'] == 0]
# Out:
#       id   age     age_group  gender   bmi    rmssd  stress_score  \
# 84     2  >=30        adults  female   <19   23.443           0.0
# 109    2  >=30        adults  female   <19   40.069           0.0
# 123    2  >=30        adults  female   <19   38.155           0.0
# 128    2  >=30        adults  female   <19   32.229           0.0
# 142    3  >=30        adults  female  22.0   22.635           0.0
# ...   ..   ...           ...     ...   ...      ...           ...
# 1477  30   <30  young adults  female  >=25   48.530           0.0
# 1489  30   <30  young adults  female  >=25  100.366           0.0
# 1495  30   <30  young adults  female  >=25   74.455           0.0
# 1505  30   <30  young adults  female  >=25   80.609           0.0
# 1519  31   <30  young adults  female  23.0   18.366           0.0
#
#       sleep_points_percentage  calories  distance        bpm  \
# 84                        0.0   2166.83   11504.4  84.315467
# ...

# %%
sns.countplot(data=fitbit_data, x='age_group')
plt.title('age_group Distribution')
plt.xlabel('age_group')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# plt.figure(figsize=(8,6))
# plt.scatter(fitbit_data['stress_score'], fitbit_data['sleep_points_percentage'], alpha=0.7)
# plt.xlabel('stress_score')
# plt.ylabel('sleep_points_percentage')
# plt.title('Stress Score vs. Sleep Points Percentage')
# plt.grid(True)
# plt.show()

# plt.figure(figsize=(8,6))
# sns.scatterplot(data=fitbit_data, x='stress_score', y='id')
# plt.title('Stress Score vs. Sleep Points Percentage')
# plt.show()

plt.figure(figsize=(10,6))
sns.barplot(data=fitbit_data, x='stress_score', y='id', orient='h')
plt.title('Durchschnittlicher Stress Score pro ID')
plt.xlabel('Stress Score')
plt.ylabel('ID')
plt.tight_layout()
plt.show()

# %%
sns.boxplot(data=fitbit_data, x='age', y='bmi')
plt.title('bmi by age')
plt.xlabel('age')
plt.ylabel('bmi')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(fitbit_data.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
