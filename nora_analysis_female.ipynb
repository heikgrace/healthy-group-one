# %%
import pandas as pd
import numpy as np

# %%
data_female = pd.read_csv("data/sleephealthlifestyle/data_gender_female.csv")

# %%
data_female.head()
# Out:
#    gender    age_group  age occupation  sleep_duration  quality_of_sleep  \
# 0  Female  Young Adult   29      Nurse             6.5                 5
# 1  Female  Young Adult   29      Nurse             6.5                 5
# 2  Female  Young Adult   30      Nurse             6.4                 5
# 3  Female  Young Adult   30      Nurse             6.4                 5
# 4  Female  Young Adult   31      Nurse             7.9                 8
#
#    physical_activity_level  stress_level   bmi_category  \
# 0                       40             7  Normal Weight
# 1                       40             7  Normal Weight
# 2                       35             7  Normal Weight
# 3                       35             7  Normal Weight
# 4                       75             4  Normal Weight
#
#    blood_pressure_systolic  blood_pressure_diastolic  heart_rate  daily_steps  \
# 0                      132                        87          80         4000
# ...

# %%
data_female.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    185 non-null    object
#  1   age_group                 185 non-null    object
#  2   age                       185 non-null    int64
#  3   occupation                185 non-null    object
#  4   sleep_duration            185 non-null    float64
#  5   quality_of_sleep          185 non-null    int64
#  6   physical_activity_level   185 non-null    int64
#  7   stress_level              185 non-null    int64
#  8   bmi_category              185 non-null    object
#  9   blood_pressure_systolic   185 non-null    int64
#  10  blood_pressure_diastolic  185 non-null    int64
#  11  heart_rate                185 non-null    int64
#  12  daily_steps               185 non-null    int64
#  13  sleep_disorder            103 non-null    object
# ...

# %%
#data_female['Sleep Disorder'].fillna("Unknown", inplace=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(data=data_female, x='age', bins=10, kde=True)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
sns.countplot(data=data_female, x='bmi_category')
plt.title('BMI Category Distribution')
plt.xlabel('BMI Category')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# Merge Normal and Normal weight

#ata_female['BMI Category'] = data_female['BMI Category'].replace('Normal', 'Normal Weight')

# %%
sns.countplot(data=data_female, x='bmi_category')
plt.title('BMI Category Distribution')
plt.xlabel('BMI Category')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
sns.barplot(data=data_female, x='Age_group', y='Sleep Duration', estimator='mean')
plt.title('Average Sleep Duration by Age Group')
plt.ylabel('Sleep Duration (hours)')
plt.show()

# %%
sns.boxplot(data=data_female, x='Sleep Disorder', y='Stress Level')
plt.title('Stress Level by Sleep Disorder')
plt.xlabel('Sleep Disorder')
plt.ylabel('Stress Level')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(data_female.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.boxplot(data=data_female, x='BMI Category', y='Physical Activity Level')
plt.title('Physical Activity Level by BMI Category')
plt.xticks(rotation=45)
plt.show()

# %%
#Stress Level by BMI Category
sns.boxplot(data=data_female, x='BMI Category', y='Stress Level')

plt.xticks(rotation=45)
plt.show()

# %%
#Sleep Quality by BMI and Sleep Disorder

sns.boxplot(data=data_female, x='BMI Category', y='Quality of Sleep', hue='Sleep Disorder')

plt.xticks(rotation=45)
plt.show()

# %%
sns.scatterplot(data=data_female, x='Stress Level', y='Quality of Sleep', hue='BMI Category')
plt.title('Quality of Sleep vs Stress Level')
plt.show()
